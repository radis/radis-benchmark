# %% [markdown]
# ### Import Stuff

# %%
# !pip install radis
# !pip install memory_profiler

from radis.db.classes import get_molecule_identifier
from radis.levels.partfunc import PartFuncHAPI

from radis.io.hitemp import fetch_hitemp
from radis.db.classes import get_molecule
from radis.phys.constants import hc_k

import numpy as np
from numpy import exp, pi

# %load_ext memory_profiler

# %% [markdown]
# ### Function to retrieve Qgas value from partition table

# %%
def get_Qgas(molecule, iso, T):

    M = get_molecule_identifier(molecule)

    Q = PartFuncHAPI(M, iso)
    return Q.at(T=T)

# %% [markdown]
# ### Convert list to dictionary

# %%
def list_to_dict(list0):

  dict0 = dict() 
  for index,value in enumerate(list0):
    dict0[index] = value
  
  return dict0

# %% [markdown]
# ### Old function to used to scale linestrength values

# %%
def calc_linestrength_eq(df, Tref, Tgas):
  if len(df) == 0:
          return

    
  print("Scaling equilibrium linestrength")

  # %% Load partition function values

  def _calc_Q(molecule, iso, T_ref, T_gas):

      Qref = get_Qgas(molecule, iso, T_ref)
      Qgas = get_Qgas(molecule, iso, T_gas)


      return Qref, Qgas

  id_set = df.id.unique()
  id = list(id_set)[0]
  molecule = get_molecule(id) # retrieve the molecule
  iso_set = set(df.iso)  # df1.iso.unique()

  # when we have only one isotope Qref, Qgas are stored as attributes
  if len(iso_set) == 1:
      Qref, Qgas = _calc_Q(molecule, iso_set[0], T_gas, T_ref)
      df.Qref = float(Qref) 
      df.Qgas = float(Qgas)
      assert "Qref" not in df.columns
      assert "Qgas" not in df.columns

  # when we have more than one isotope Qref, Qgas are stored as separate columns
  else:

      iso_arr = list(range(max(iso_set) + 1))

      Qref_arr = np.empty_like(iso_arr, dtype=np.float64)
      Qgas_arr = np.empty_like(iso_arr, dtype=np.float64)
      for iso in iso_arr:
          if iso in iso_set:
              Qref, Qgas = _calc_Q(molecule, iso, Tref, Tgas)
              Qref_arr[iso] = Qref
              Qgas_arr[iso] = Qgas

      df["Qref"] = Qref_arr.take(df.iso)
      df["Qgas"] = Qgas_arr.take(df.iso)

  # Scaling linestrength with the equations from Rotham's paper
  line_strength = df.int * (df.Qref / df.Qgas)
  #line_strength = df.int * (Qref_arr.take(df.iso) / Qgas_arr.take(df.iso))
  line_strength *= exp(-hc_k * df.El * (1 / Tgas - 1 / Tref))
  line_strength *= (1 - exp(-hc_k * df.wav / Tgas)) / (
      1 - exp(-hc_k * df.wav / Tref)
  )
  # Add a fresh columns with the scaled linestrength
  df["S"] = line_strength  # [cm-1/(molecules/cm-2)]

  # Just to make sure linestrength is indeed added
  assert "S" in df

  return df

# %% [markdown]
# ### Scale linstrengths with the new method

# %%
def calc_linestrength_eq_optimised(df, Tref, Tgas):
  if len(df) == 0:
          return

  if "Qref" in df:
    print("yes Qref here")
  
  else:
    print("not Qref here")

    
  print("Scaling equilibrium linestrength")

  # %% Load partition function values

  def _calc_Q(molecule, iso, T_ref, T_gas):

      Qref = get_Qgas(molecule, iso, T_ref)
      Qgas = get_Qgas(molecule, iso, T_gas)


      return Qref, Qgas

  id_set = df.id.unique()
  id = list(id_set)[0]
  molecule = get_molecule(id) # retrieve the molecule
  iso_set = set(df.iso)  # df1.iso.unique()

  # when we have only one isotope Qref, Qgas are stored as attributes
  if len(iso_set) == 1:
      Qref, Qgas = _calc_Q(molecule, iso_set[0], T_gas, T_ref)
      df.Qref = float(Qref) 
      df.Qgas = float(Qgas)
      assert "Qref" not in df.columns
      assert "Qgas" not in df.columns

  # when we have more than one isotope Qref, Qgas are stored as separate columns
  else:

      iso_arr = list(range(max(iso_set) + 1))

      Qref_arr = np.empty_like(iso_arr, dtype=np.float64)
      Qgas_arr = np.empty_like(iso_arr, dtype=np.float64)
      for iso in iso_arr:
          if iso in iso_set:
              Qref, Qgas = _calc_Q(molecule, iso, Tref, Tgas)
              Qref_arr[iso] = Qref
              Qgas_arr[iso] = Qgas
      
      # convert dictionaries to lists
      Qref_dict = list_to_dict(Qref_arr)
      Qgas_dict = list_to_dict(Qgas_arr)

      Qref_Qgas_ratio = {k: Qref_dict.get(k, 0) / Qgas_dict.get(k, 0) for k in set(Qref_dict) | set(Qgas_dict)}

      #copy iso column
      df["S"] = df["iso"]

      #map the ratios in the dictionary to the iso column vallues 
      df["S"].map(Qref_Qgas_ratio).fillna(df["S"])

  # Scaling linestrength with the equations from Rotham's paper
  line_strength = df.int * (df.S)
  line_strength *= exp(-hc_k * df.El * (1 / Tgas - 1 / Tref))
  line_strength *= (1 - exp(-hc_k * df.wav / Tgas)) / (
      1 - exp(-hc_k * df.wav / Tref)
  )
  # Add a fresh columns with the scaled linestrength
  df["S"] = line_strength  # [cm-1/(molecules/cm-2)]

  # Just to make sure linestrength is indeed added
  assert "S" in df

  return df

# %% [markdown]
# ### Fetch Hitemp
#
# I am using HITEMP-CH4 to test this, first with the old method.

# %%
Tref = 296 # The reference temperature is constant throughout radis

df0 = fetch_hitemp(molecule='CH4', databank_name='HITEMP-CH4', isotope='1, 2, 3', load_wavenum_min=2000, load_wavenum_max=3000)

print("================Before computation=====================")
print(df0.head())

Tgas = 300 # Any temperature of your choice at which you would like to scale linestrength

# %time df0 = calc_linestrength_eq(df0, Tref, Tgas)

print("================After computation Old=====================")
print(df0.head())
df0.info(verbose=False, memory_usage="deep")
# Out:
# Created folder : /root/.radisdb
# Downloading 06_HITEMP2020.par.bz2 for CH4.
# Download complete. Building CH4 database to /root/.radisdb/CH4-06_HITEMP2020.h5
# parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (2s)	0.3%	Parsed 100,000 / 31,880,412 lines. Wavenumber range 0.03-100.35 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (5s)	0.6%	Parsed 200,000 / 31,880,412 lines. Wavenumber range 0.03-144.01 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (7s)	0.9%	Parsed 300,000 / 31,880,412 lines. Wavenumber range 0.03-173.73 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (10s)	1.3%	Parsed 400,000 / 31,880,412 lines. Wavenumber range 0.03-196.67 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (12s)	1.6%	Parsed 500,000 / 31,880,412 lines. Wavenumber range 0.03-216.58 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (15s)	1.9%	Parsed 600,000 / 31,880,412 lines. Wavenumber range 0.03-234.77 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (17s)	2.2%	Parsed 700,000 / 31,880,412 lines. Wavenumber range 0.03-251.15 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (20s)	2.5%	Parsed 800,000 / 31,880,412 lines. Wavenumber range 0.03-266.44 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (22s)	2.8%	Parsed 900,000 / 31,880,412 lines. Wavenumber range 0.03-281.25 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (25s)	3.1%	Parsed 1,000,000 / 31,880,412 lines. Wavenumber range 0.03-295.72 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (27s)	3.5%	Parsed 1,100,000 / 31,880,412 lines. Wavenumber range 0.03-310.06 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (30s)	3.8%	Parsed 1,200,000 / 31,880,412 lines. Wavenumber range 0.03-324.36 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (32s)	4.1%	Parsed 1,300,000 / 31,880,412 lines. Wavenumber range 0.03-338.90 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (35s)	4.4%	Parsed 1,400,000 / 31,880,412 lines. Wavenumber range 0.03-353.57 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (38s)	4.7%	Parsed 1,500,000 / 31,880,412 lines. Wavenumber range 0.03-368.79 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (40s)	5.0%	Parsed 1,600,000 / 31,880,412 lines. Wavenumber range 0.03-384.64 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (43s)	5.3%	Parsed 1,700,000 / 31,880,412 lines. Wavenumber range 0.03-401.36 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (45s)	5.6%	Parsed 1,800,000 / 31,880,412 lines. Wavenumber range 0.03-418.97 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (48s)	6.0%	Parsed 1,900,000 / 31,880,412 lines. Wavenumber range 0.03-438.64 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (50s)	6.3%	Parsed 2,000,000 / 31,880,412 lines. Wavenumber range 0.03-462.17 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (53s)	6.6%	Parsed 2,100,000 / 31,880,412 lines. Wavenumber range 0.03-491.79 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (55s)	6.9%	Parsed 2,200,000 / 31,880,412 lines. Wavenumber range 0.03-532.93 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (58s)	7.2%	Parsed 2,300,000 / 31,880,412 lines. Wavenumber range 0.03-601.28 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (60s)	7.5%	Parsed 2,400,000 / 31,880,412 lines. Wavenumber range 0.03-727.33 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (63s)	7.8%	Parsed 2,500,000 / 31,880,412 lines. Wavenumber range 0.03-861.14 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (65s)	8.2%	Parsed 2,600,000 / 31,880,412 lines. Wavenumber range 0.03-942.22 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (68s)	8.5%	Parsed 2,700,000 / 31,880,412 lines. Wavenumber range 0.03-989.47 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (70s)	8.8%	Parsed 2,800,000 / 31,880,412 lines. Wavenumber range 0.03-1020.60 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (73s)	9.1%	Parsed 2,900,000 / 31,880,412 lines. Wavenumber range 0.03-1043.11 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (75s)	9.4%	Parsed 3,000,000 / 31,880,412 lines. Wavenumber range 0.03-1061.07 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (77s)	9.7%	Parsed 3,100,000 / 31,880,412 lines. Wavenumber range 0.03-1075.94 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (80s)	10.0%	Parsed 3,200,000 / 31,880,412 lines. Wavenumber range 0.03-1088.76 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (83s)	10.4%	Parsed 3,300,000 / 31,880,412 lines. Wavenumber range 0.03-1100.03 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (85s)	10.7%	Parsed 3,400,000 / 31,880,412 lines. Wavenumber range 0.03-1110.08 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (88s)	11.0%	Parsed 3,500,000 / 31,880,412 lines. Wavenumber range 0.03-1119.11 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (90s)	11.3%	Parsed 3,600,000 / 31,880,412 lines. Wavenumber range 0.03-1127.23 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (93s)	11.6%	Parsed 3,700,000 / 31,880,412 lines. Wavenumber range 0.03-1134.52 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (95s)	11.9%	Parsed 3,800,000 / 31,880,412 lines. Wavenumber range 0.03-1141.07 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (98s)	12.2%	Parsed 3,900,000 / 31,880,412 lines. Wavenumber range 0.03-1147.00 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (100s)	12.5%	Parsed 4,000,000 / 31,880,412 lines. Wavenumber range 0.03-1152.44 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (103s)	12.9%	Parsed 4,100,000 / 31,880,412 lines. Wavenumber range 0.03-1157.57 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (105s)	13.2%	Parsed 4,200,000 / 31,880,412 lines. Wavenumber range 0.03-1162.44 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (108s)	13.5%	Parsed 4,300,000 / 31,880,412 lines. Wavenumber range 0.03-1167.14 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (110s)	13.8%	Parsed 4,400,000 / 31,880,412 lines. Wavenumber range 0.03-1171.70 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (113s)	14.1%	Parsed 4,500,000 / 31,880,412 lines. Wavenumber range 0.03-1176.15 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (115s)	14.4%	Parsed 4,600,000 / 31,880,412 lines. Wavenumber range 0.03-1180.50 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (118s)	14.7%	Parsed 4,700,000 / 31,880,412 lines. Wavenumber range 0.03-1184.83 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (120s)	15.1%	Parsed 4,800,000 / 31,880,412 lines. Wavenumber range 0.03-1189.21 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (123s)	15.4%	Parsed 4,900,000 / 31,880,412 lines. Wavenumber range 0.03-1193.70 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (125s)	15.7%	Parsed 5,000,000 / 31,880,412 lines. Wavenumber range 0.03-1198.38 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (127s)	16.0%	Parsed 5,100,000 / 31,880,412 lines. Wavenumber range 0.03-1203.28 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (130s)	16.3%	Parsed 5,200,000 / 31,880,412 lines. Wavenumber range 0.03-1208.32 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (132s)	16.6%	Parsed 5,300,000 / 31,880,412 lines. Wavenumber range 0.03-1213.41 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (135s)	16.9%	Parsed 5,400,000 / 31,880,412 lines. Wavenumber range 0.03-1218.37 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (137s)	17.3%	Parsed 5,500,000 / 31,880,412 lines. Wavenumber range 0.03-1223.03 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (140s)	17.6%	Parsed 5,600,000 / 31,880,412 lines. Wavenumber range 0.03-1227.42 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (142s)	17.9%	Parsed 5,700,000 / 31,880,412 lines. Wavenumber range 0.03-1231.47 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (145s)	18.2%	Parsed 5,800,000 / 31,880,412 lines. Wavenumber range 0.03-1235.26 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (147s)	18.5%	Parsed 5,900,000 / 31,880,412 lines. Wavenumber range 0.03-1238.77 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (149s)	18.8%	Parsed 6,000,000 / 31,880,412 lines. Wavenumber range 0.03-1242.08 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (152s)	19.1%	Parsed 6,100,000 / 31,880,412 lines. Wavenumber range 0.03-1245.14 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (154s)	19.4%	Parsed 6,200,000 / 31,880,412 lines. Wavenumber range 0.03-1248.00 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (157s)	19.8%	Parsed 6,300,000 / 31,880,412 lines. Wavenumber range 0.03-1250.66 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (159s)	20.1%	Parsed 6,400,000 / 31,880,412 lines. Wavenumber range 0.03-1253.14 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (161s)	20.4%	Parsed 6,500,000 / 31,880,412 lines. Wavenumber range 0.03-1255.48 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (164s)	20.7%	Parsed 6,600,000 / 31,880,412 lines. Wavenumber range 0.03-1257.69 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (166s)	21.0%	Parsed 6,700,000 / 31,880,412 lines. Wavenumber range 0.03-1259.78 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (168s)	21.3%	Parsed 6,800,000 / 31,880,412 lines. Wavenumber range 0.03-1261.84 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (171s)	21.6%	Parsed 6,900,000 / 31,880,412 lines. Wavenumber range 0.03-1263.88 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (173s)	22.0%	Parsed 7,000,000 / 31,880,412 lines. Wavenumber range 0.03-1265.90 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (176s)	22.3%	Parsed 7,100,000 / 31,880,412 lines. Wavenumber range 0.03-1267.96 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (178s)	22.6%	Parsed 7,200,000 / 31,880,412 lines. Wavenumber range 0.03-1270.06 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (181s)	22.9%	Parsed 7,300,000 / 31,880,412 lines. Wavenumber range 0.03-1272.23 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (183s)	23.2%	Parsed 7,400,000 / 31,880,412 lines. Wavenumber range 0.03-1274.51 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (186s)	23.5%	Parsed 7,500,000 / 31,880,412 lines. Wavenumber range 0.03-1276.99 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (188s)	23.8%	Parsed 7,600,000 / 31,880,412 lines. Wavenumber range 0.03-1279.71 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (191s)	24.2%	Parsed 7,700,000 / 31,880,412 lines. Wavenumber range 0.03-1282.74 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (193s)	24.5%	Parsed 7,800,000 / 31,880,412 lines. Wavenumber range 0.03-1286.31 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (196s)	24.8%	Parsed 7,900,000 / 31,880,412 lines. Wavenumber range 0.03-1290.41 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (198s)	25.1%	Parsed 8,000,000 / 31,880,412 lines. Wavenumber range 0.03-1295.03 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (200s)	25.4%	Parsed 8,100,000 / 31,880,412 lines. Wavenumber range 0.03-1299.89 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (203s)	25.7%	Parsed 8,200,000 / 31,880,412 lines. Wavenumber range 0.03-1304.84 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (206s)	26.0%	Parsed 8,300,000 / 31,880,412 lines. Wavenumber range 0.03-1309.70 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (208s)	26.3%	Parsed 8,400,000 / 31,880,412 lines. Wavenumber range 0.03-1314.48 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (210s)	26.7%	Parsed 8,500,000 / 31,880,412 lines. Wavenumber range 0.03-1319.10 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (213s)	27.0%	Parsed 8,600,000 / 31,880,412 lines. Wavenumber range 0.03-1323.59 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (216s)	27.3%	Parsed 8,700,000 / 31,880,412 lines. Wavenumber range 0.03-1327.92 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (218s)	27.6%	Parsed 8,800,000 / 31,880,412 lines. Wavenumber range 0.03-1332.22 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (221s)	27.9%	Parsed 8,900,000 / 31,880,412 lines. Wavenumber range 0.03-1336.50 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (223s)	28.2%	Parsed 9,000,000 / 31,880,412 lines. Wavenumber range 0.03-1340.85 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (226s)	28.5%	Parsed 9,100,000 / 31,880,412 lines. Wavenumber range 0.03-1345.32 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (228s)	28.9%	Parsed 9,200,000 / 31,880,412 lines. Wavenumber range 0.03-1350.02 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (231s)	29.2%	Parsed 9,300,000 / 31,880,412 lines. Wavenumber range 0.03-1354.95 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (233s)	29.5%	Parsed 9,400,000 / 31,880,412 lines. Wavenumber range 0.03-1360.13 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (236s)	29.8%	Parsed 9,500,000 / 31,880,412 lines. Wavenumber range 0.03-1365.35 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (238s)	30.1%	Parsed 9,600,000 / 31,880,412 lines. Wavenumber range 0.03-1370.56 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (240s)	30.4%	Parsed 9,700,000 / 31,880,412 lines. Wavenumber range 0.03-1375.74 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (243s)	30.7%	Parsed 9,800,000 / 31,880,412 lines. Wavenumber range 0.03-1381.02 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (245s)	31.1%	Parsed 9,900,000 / 31,880,412 lines. Wavenumber range 0.03-1386.59 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (248s)	31.4%	Parsed 10,000,000 / 31,880,412 lines. Wavenumber range 0.03-1392.53 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (250s)	31.7%	Parsed 10,100,000 / 31,880,412 lines. Wavenumber range 0.03-1398.99 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (253s)	32.0%	Parsed 10,200,000 / 31,880,412 lines. Wavenumber range 0.03-1406.20 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (255s)	32.3%	Parsed 10,300,000 / 31,880,412 lines. Wavenumber range 0.03-1414.50 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (258s)	32.6%	Parsed 10,400,000 / 31,880,412 lines. Wavenumber range 0.03-1424.33 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (260s)	32.9%	Parsed 10,500,000 / 31,880,412 lines. Wavenumber range 0.03-1436.04 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (263s)	33.2%	Parsed 10,600,000 / 31,880,412 lines. Wavenumber range 0.03-1449.73 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (266s)	33.6%	Parsed 10,700,000 / 31,880,412 lines. Wavenumber range 0.03-1466.32 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (268s)	33.9%	Parsed 10,800,000 / 31,880,412 lines. Wavenumber range 0.03-1490.18 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (271s)	34.2%	Parsed 10,900,000 / 31,880,412 lines. Wavenumber range 0.03-1521.20 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (273s)	34.5%	Parsed 11,000,000 / 31,880,412 lines. Wavenumber range 0.03-1541.47 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (276s)	34.8%	Parsed 11,100,000 / 31,880,412 lines. Wavenumber range 0.03-1559.43 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (278s)	35.1%	Parsed 11,200,000 / 31,880,412 lines. Wavenumber range 0.03-1579.30 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (281s)	35.4%	Parsed 11,300,000 / 31,880,412 lines. Wavenumber range 0.03-1602.23 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (283s)	35.8%	Parsed 11,400,000 / 31,880,412 lines. Wavenumber range 0.03-1624.53 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (286s)	36.1%	Parsed 11,500,000 / 31,880,412 lines. Wavenumber range 0.03-1646.10 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (289s)	36.4%	Parsed 11,600,000 / 31,880,412 lines. Wavenumber range 0.03-1669.50 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (291s)	36.7%	Parsed 11,700,000 / 31,880,412 lines. Wavenumber range 0.03-1698.12 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (294s)	37.0%	Parsed 11,800,000 / 31,880,412 lines. Wavenumber range 0.03-1721.73 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (296s)	37.3%	Parsed 11,900,000 / 31,880,412 lines. Wavenumber range 0.03-1758.92 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (298s)	37.6%	Parsed 12,000,000 / 31,880,412 lines. Wavenumber range 0.03-1796.33 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (301s)	38.0%	Parsed 12,100,000 / 31,880,412 lines. Wavenumber range 0.03-1832.59 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (303s)	38.3%	Parsed 12,200,000 / 31,880,412 lines. Wavenumber range 0.03-1876.90 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (306s)	38.6%	Parsed 12,300,000 / 31,880,412 lines. Wavenumber range 0.03-1935.37 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (308s)	38.9%	Parsed 12,400,000 / 31,880,412 lines. Wavenumber range 0.03-2011.18 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (311s)	39.2%	Parsed 12,500,000 / 31,880,412 lines. Wavenumber range 0.03-2128.27 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (313s)	39.5%	Parsed 12,600,000 / 31,880,412 lines. Wavenumber range 0.03-2308.69 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (316s)	39.8%	Parsed 12,700,000 / 31,880,412 lines. Wavenumber range 0.03-2472.51 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (318s)	40.2%	Parsed 12,800,000 / 31,880,412 lines. Wavenumber range 0.03-2589.81 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (321s)	40.5%	Parsed 12,900,000 / 31,880,412 lines. Wavenumber range 0.03-2667.21 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (323s)	40.8%	Parsed 13,000,000 / 31,880,412 lines. Wavenumber range 0.03-2716.77 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (326s)	41.1%	Parsed 13,100,000 / 31,880,412 lines. Wavenumber range 0.03-2752.62 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (328s)	41.4%	Parsed 13,200,000 / 31,880,412 lines. Wavenumber range 0.03-2783.99 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (331s)	41.7%	Parsed 13,300,000 / 31,880,412 lines. Wavenumber range 0.03-2811.49 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (333s)	42.0%	Parsed 13,400,000 / 31,880,412 lines. Wavenumber range 0.03-2835.19 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (336s)	42.3%	Parsed 13,500,000 / 31,880,412 lines. Wavenumber range 0.03-2859.96 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (338s)	42.7%	Parsed 13,600,000 / 31,880,412 lines. Wavenumber range 0.03-2890.33 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (341s)	43.0%	Parsed 13,700,000 / 31,880,412 lines. Wavenumber range 0.03-2916.50 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (343s)	43.3%	Parsed 13,800,000 / 31,880,412 lines. Wavenumber range 0.03-2934.94 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (346s)	43.6%	Parsed 13,900,000 / 31,880,412 lines. Wavenumber range 0.03-2952.08 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (348s)	43.9%	Parsed 14,000,000 / 31,880,412 lines. Wavenumber range 0.03-2962.62 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (351s)	44.2%	Parsed 14,100,000 / 31,880,412 lines. Wavenumber range 0.03-2969.90 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (353s)	44.5%	Parsed 14,200,000 / 31,880,412 lines. Wavenumber range 0.03-2976.71 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (356s)	44.9%	Parsed 14,300,000 / 31,880,412 lines. Wavenumber range 0.03-2984.77 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (358s)	45.2%	Parsed 14,400,000 / 31,880,412 lines. Wavenumber range 0.03-2995.70 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (361s)	45.5%	Parsed 14,500,000 / 31,880,412 lines. Wavenumber range 0.03-3013.18 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (363s)	45.8%	Parsed 14,600,000 / 31,880,412 lines. Wavenumber range 0.03-3042.91 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (365s)	46.1%	Parsed 14,700,000 / 31,880,412 lines. Wavenumber range 0.03-3068.34 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (368s)	46.4%	Parsed 14,800,000 / 31,880,412 lines. Wavenumber range 0.03-3090.53 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (370s)	46.7%	Parsed 14,900,000 / 31,880,412 lines. Wavenumber range 0.03-3111.23 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (373s)	47.1%	Parsed 15,000,000 / 31,880,412 lines. Wavenumber range 0.03-3131.53 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (375s)	47.4%	Parsed 15,100,000 / 31,880,412 lines. Wavenumber range 0.03-3153.30 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (378s)	47.7%	Parsed 15,200,000 / 31,880,412 lines. Wavenumber range 0.03-3174.60 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (380s)	48.0%	Parsed 15,300,000 / 31,880,412 lines. Wavenumber range 0.03-3198.15 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (383s)	48.3%	Parsed 15,400,000 / 31,880,412 lines. Wavenumber range 0.03-3227.50 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (385s)	48.6%	Parsed 15,500,000 / 31,880,412 lines. Wavenumber range 0.03-3270.34 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (388s)	48.9%	Parsed 15,600,000 / 31,880,412 lines. Wavenumber range 0.03-3366.08 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (390s)	49.2%	Parsed 15,700,000 / 31,880,412 lines. Wavenumber range 0.03-3597.92 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (393s)	49.6%	Parsed 15,800,000 / 31,880,412 lines. Wavenumber range 0.03-3771.47 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (395s)	49.9%	Parsed 15,900,000 / 31,880,412 lines. Wavenumber range 0.03-3871.92 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (398s)	50.2%	Parsed 16,000,000 / 31,880,412 lines. Wavenumber range 0.03-3951.44 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (400s)	50.5%	Parsed 16,100,000 / 31,880,412 lines. Wavenumber range 0.03-4003.62 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (402s)	50.8%	Parsed 16,200,000 / 31,880,412 lines. Wavenumber range 0.03-4043.93 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (405s)	51.1%	Parsed 16,300,000 / 31,880,412 lines. Wavenumber range 0.03-4078.72 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (408s)	51.4%	Parsed 16,400,000 / 31,880,412 lines. Wavenumber range 0.03-4110.33 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (410s)	51.8%	Parsed 16,500,000 / 31,880,412 lines. Wavenumber range 0.03-4139.13 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (413s)	52.1%	Parsed 16,600,000 / 31,880,412 lines. Wavenumber range 0.03-4164.30 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (415s)	52.4%	Parsed 16,700,000 / 31,880,412 lines. Wavenumber range 0.03-4188.60 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (418s)	52.7%	Parsed 16,800,000 / 31,880,412 lines. Wavenumber range 0.03-4216.34 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (420s)	53.0%	Parsed 16,900,000 / 31,880,412 lines. Wavenumber range 0.03-4241.36 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (422s)	53.3%	Parsed 17,000,000 / 31,880,412 lines. Wavenumber range 0.03-4263.82 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (425s)	53.6%	Parsed 17,100,000 / 31,880,412 lines. Wavenumber range 0.03-4287.61 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (427s)	54.0%	Parsed 17,200,000 / 31,880,412 lines. Wavenumber range 0.03-4314.41 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (430s)	54.3%	Parsed 17,300,000 / 31,880,412 lines. Wavenumber range 0.03-4340.80 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (432s)	54.6%	Parsed 17,400,000 / 31,880,412 lines. Wavenumber range 0.03-4369.08 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (435s)	54.9%	Parsed 17,500,000 / 31,880,412 lines. Wavenumber range 0.03-4403.31 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (437s)	55.2%	Parsed 17,600,000 / 31,880,412 lines. Wavenumber range 0.03-4441.67 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (440s)	55.5%	Parsed 17,700,000 / 31,880,412 lines. Wavenumber range 0.03-4483.54 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (442s)	55.8%	Parsed 17,800,000 / 31,880,412 lines. Wavenumber range 0.03-4519.19 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (444s)	56.1%	Parsed 17,900,000 / 31,880,412 lines. Wavenumber range 0.03-4564.32 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (447s)	56.5%	Parsed 18,000,000 / 31,880,412 lines. Wavenumber range 0.03-4636.36 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (449s)	56.8%	Parsed 18,100,000 / 31,880,412 lines. Wavenumber range 0.03-4748.38 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (452s)	57.1%	Parsed 18,200,000 / 31,880,412 lines. Wavenumber range 0.03-4905.74 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (454s)	57.4%	Parsed 18,300,000 / 31,880,412 lines. Wavenumber range 0.03-5070.43 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (457s)	57.7%	Parsed 18,400,000 / 31,880,412 lines. Wavenumber range 0.03-5162.10 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (459s)	58.0%	Parsed 18,500,000 / 31,880,412 lines. Wavenumber range 0.03-5219.36 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (462s)	58.3%	Parsed 18,600,000 / 31,880,412 lines. Wavenumber range 0.03-5262.74 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (464s)	58.7%	Parsed 18,700,000 / 31,880,412 lines. Wavenumber range 0.03-5296.59 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (467s)	59.0%	Parsed 18,800,000 / 31,880,412 lines. Wavenumber range 0.03-5323.84 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (469s)	59.3%	Parsed 18,900,000 / 31,880,412 lines. Wavenumber range 0.03-5350.70 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (471s)	59.6%	Parsed 19,000,000 / 31,880,412 lines. Wavenumber range 0.03-5378.82 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (474s)	59.9%	Parsed 19,100,000 / 31,880,412 lines. Wavenumber range 0.03-5407.35 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (476s)	60.2%	Parsed 19,200,000 / 31,880,412 lines. Wavenumber range 0.03-5435.15 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (479s)	60.5%	Parsed 19,300,000 / 31,880,412 lines. Wavenumber range 0.03-5460.23 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (481s)	60.9%	Parsed 19,400,000 / 31,880,412 lines. Wavenumber range 0.03-5482.46 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (484s)	61.2%	Parsed 19,500,000 / 31,880,412 lines. Wavenumber range 0.03-5503.89 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (486s)	61.5%	Parsed 19,600,000 / 31,880,412 lines. Wavenumber range 0.03-5526.55 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (489s)	61.8%	Parsed 19,700,000 / 31,880,412 lines. Wavenumber range 0.03-5550.37 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (491s)	62.1%	Parsed 19,800,000 / 31,880,412 lines. Wavenumber range 0.03-5575.21 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (494s)	62.4%	Parsed 19,900,000 / 31,880,412 lines. Wavenumber range 0.03-5599.74 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (496s)	62.7%	Parsed 20,000,000 / 31,880,412 lines. Wavenumber range 0.03-5624.81 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (499s)	63.0%	Parsed 20,100,000 / 31,880,412 lines. Wavenumber range 0.03-5651.63 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (502s)	63.4%	Parsed 20,200,000 / 31,880,412 lines. Wavenumber range 0.03-5676.38 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (504s)	63.7%	Parsed 20,300,000 / 31,880,412 lines. Wavenumber range 0.03-5699.04 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (507s)	64.0%	Parsed 20,400,000 / 31,880,412 lines. Wavenumber range 0.03-5722.08 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (509s)	64.3%	Parsed 20,500,000 / 31,880,412 lines. Wavenumber range 0.03-5749.45 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# ...
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (648s)	81.6%	Parsed 26,000,000 / 31,880,412 lines. Wavenumber range 0.03-8980.80 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (651s)	81.9%	Parsed 26,100,000 / 31,880,412 lines. Wavenumber range 0.03-9065.74 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (653s)	82.2%	Parsed 26,200,000 / 31,880,412 lines. Wavenumber range 0.03-9252.10 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (656s)	82.5%	Parsed 26,300,000 / 31,880,412 lines. Wavenumber range 0.03-9459.12 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (658s)	82.8%	Parsed 26,400,000 / 31,880,412 lines. Wavenumber range 0.03-9610.37 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (661s)	83.1%	Parsed 26,500,000 / 31,880,412 lines. Wavenumber range 0.03-9696.52 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (663s)	83.4%	Parsed 26,600,000 / 31,880,412 lines. Wavenumber range 0.03-9758.58 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (666s)	83.8%	Parsed 26,700,000 / 31,880,412 lines. Wavenumber range 0.03-9809.99 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (668s)	84.1%	Parsed 26,800,000 / 31,880,412 lines. Wavenumber range 0.03-9852.43 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (671s)	84.4%	Parsed 26,900,000 / 31,880,412 lines. Wavenumber range 0.03-9891.46 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (673s)	84.7%	Parsed 27,000,000 / 31,880,412 lines. Wavenumber range 0.03-9928.67 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (676s)	85.0%	Parsed 27,100,000 / 31,880,412 lines. Wavenumber range 0.03-9966.45 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (678s)	85.3%	Parsed 27,200,000 / 31,880,412 lines. Wavenumber range 0.03-10006.75 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (681s)	85.6%	Parsed 27,300,000 / 31,880,412 lines. Wavenumber range 0.03-10053.45 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (683s)	85.9%	Parsed 27,400,000 / 31,880,412 lines. Wavenumber range 0.03-10101.32 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (686s)	86.3%	Parsed 27,500,000 / 31,880,412 lines. Wavenumber range 0.03-10157.16 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (688s)	86.6%	Parsed 27,600,000 / 31,880,412 lines. Wavenumber range 0.03-10229.94 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (691s)	86.9%	Parsed 27,700,000 / 31,880,412 lines. Wavenumber range 0.03-10314.71 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (693s)	87.2%	Parsed 27,800,000 / 31,880,412 lines. Wavenumber range 0.03-10443.48 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (696s)	87.5%	Parsed 27,900,000 / 31,880,412 lines. Wavenumber range 0.03-10632.83 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (698s)	87.8%	Parsed 28,000,000 / 31,880,412 lines. Wavenumber range 0.03-10824.24 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (701s)	88.1%	Parsed 28,100,000 / 31,880,412 lines. Wavenumber range 0.03-10942.22 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (703s)	88.5%	Parsed 28,200,000 / 31,880,412 lines. Wavenumber range 0.03-11023.47 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (705s)	88.8%	Parsed 28,300,000 / 31,880,412 lines. Wavenumber range 0.03-11083.35 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (708s)	89.1%	Parsed 28,400,000 / 31,880,412 lines. Wavenumber range 0.03-11134.75 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (710s)	89.4%	Parsed 28,500,000 / 31,880,412 lines. Wavenumber range 0.03-11179.92 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (713s)	89.7%	Parsed 28,600,000 / 31,880,412 lines. Wavenumber range 0.03-11226.81 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (715s)	90.0%	Parsed 28,700,000 / 31,880,412 lines. Wavenumber range 0.03-11272.15 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (718s)	90.3%	Parsed 28,800,000 / 31,880,412 lines. Wavenumber range 0.03-11320.27 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (720s)	90.7%	Parsed 28,900,000 / 31,880,412 lines. Wavenumber range 0.03-11373.10 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (723s)	91.0%	Parsed 29,000,000 / 31,880,412 lines. Wavenumber range 0.03-11426.86 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (725s)	91.3%	Parsed 29,100,000 / 31,880,412 lines. Wavenumber range 0.03-11491.34 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (728s)	91.6%	Parsed 29,200,000 / 31,880,412 lines. Wavenumber range 0.03-11560.51 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (730s)	91.9%	Parsed 29,300,000 / 31,880,412 lines. Wavenumber range 0.03-11635.78 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (733s)	92.2%	Parsed 29,400,000 / 31,880,412 lines. Wavenumber range 0.03-11713.58 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (735s)	92.5%	Parsed 29,500,000 / 31,880,412 lines. Wavenumber range 0.03-11811.57 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (738s)	92.8%	Parsed 29,600,000 / 31,880,412 lines. Wavenumber range 0.03-11925.87 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (740s)	93.2%	Parsed 29,700,000 / 31,880,412 lines. Wavenumber range 0.03-12067.98 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (743s)	93.5%	Parsed 29,800,000 / 31,880,412 lines. Wavenumber range 0.03-12213.26 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (745s)	93.8%	Parsed 29,900,000 / 31,880,412 lines. Wavenumber range 0.03-12314.97 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (747s)	94.1%	Parsed 30,000,000 / 31,880,412 lines. Wavenumber range 0.03-12391.30 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (750s)	94.4%	Parsed 30,100,000 / 31,880,412 lines. Wavenumber range 0.03-12455.17 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (753s)	94.7%	Parsed 30,200,000 / 31,880,412 lines. Wavenumber range 0.03-12509.62 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (755s)	95.0%	Parsed 30,300,000 / 31,880,412 lines. Wavenumber range 0.03-12558.82 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (757s)	95.4%	Parsed 30,400,000 / 31,880,412 lines. Wavenumber range 0.03-12605.52 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (760s)	95.7%	Parsed 30,500,000 / 31,880,412 lines. Wavenumber range 0.03-12653.37 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (762s)	96.0%	Parsed 30,600,000 / 31,880,412 lines. Wavenumber range 0.03-12698.81 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (765s)	96.3%	Parsed 30,700,000 / 31,880,412 lines. Wavenumber range 0.03-12746.29 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (767s)	96.6%	Parsed 30,800,000 / 31,880,412 lines. Wavenumber range 0.03-12793.31 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (770s)	96.9%	Parsed 30,900,000 / 31,880,412 lines. Wavenumber range 0.03-12840.66 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (772s)	97.2%	Parsed 31,000,000 / 31,880,412 lines. Wavenumber range 0.03-12890.05 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (775s)	97.6%	Parsed 31,100,000 / 31,880,412 lines. Wavenumber range 0.03-12942.87 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (777s)	97.9%	Parsed 31,200,000 / 31,880,412 lines. Wavenumber range 0.03-12999.32 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (780s)	98.2%	Parsed 31,300,000 / 31,880,412 lines. Wavenumber range 0.03-13060.91 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (782s)	98.5%	Parsed 31,400,000 / 31,880,412 lines. Wavenumber range 0.03-13128.17 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (785s)	98.8%	Parsed 31,500,000 / 31,880,412 lines. Wavenumber range 0.03-13196.80 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (787s)	99.1%	Parsed 31,600,000 / 31,880,412 lines. Wavenumber range 0.03-13260.64 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (790s)	99.4%	Parsed 31,700,000 / 31,880,412 lines. Wavenumber range 0.03-13315.19 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (792s)	99.7%	Parsed 31,800,000 / 31,880,412 lines. Wavenumber range 0.03-13361.86 cm-1 is complete.parse_local_quanta not implemented for molecules of HITRAN group 3
# parse_global_quanta not implemented for molecules of HITRAN class 10
# (795s)	100.0%
# Created ~/radis.json in /root
# Added HITEMP-CH4 database in /root/radis.json
# ================Before computation=====================
#        id  iso         wav           int  ...          iref  lmix     gp    gpp
# 87326   6    1  2000.00250  2.852000e-42  ...  715947141313          0.0    0.0
# 87327   6    1  2000.00250  8.171000e-36  ...  715947141313          0.0    0.0
# 87328   6    1  2000.00264  3.091000e-37  ...  705832 3 3 3        255.0  245.0
# 87329   6    1  2000.00362  1.880000e-31  ...  705832 3 3 3        123.0  117.0
# 87330   6    1  2000.00375  1.288000e-39  ...  705832 3 3 3         90.0   86.0
#
# [5 rows x 19 columns]
# Scaling equilibrium linestrength
# HAPI version: 1.1.2.0
# To get the most up-to-date version please check http://hitran.org/hapi
# ATTENTION: Python versions of partition sums from TIPS-2017 are now available in HAPI code
#
#            It is free to use HAPI. If you use HAPI in your research or software development,
#            please cite it using the following reference:
#            R.V. Kochanov, I.E. Gordon, L.S. Rothman, P. Wcislo, C. Hill, J.S. Wilzewski,
#            HITRAN Application Programming Interface (HAPI): A comprehensive approach
#            to working with spectroscopic data, J. Quant. Spectrosc. Radiat. Transfer 177, 15-30 (2016)
#            DOI: 10.1016/j.jqsrt.2016.03.005
# CPU times: user 477 ms, sys: 31.2 ms, total: 509 ms
# Wall time: 474 ms
# ================After computation Old=====================
#        id  iso         wav  ...        Qref      Qgas             S
# 87326   6    1  2000.00250  ...  590.477738  602.8155  5.820099e-42
# 87327   6    1  2000.00250  ...  590.477738  602.8155  1.292129e-35
# 87328   6    1  2000.00264  ...  590.477738  602.8155  4.956589e-37
# 87329   6    1  2000.00362  ...  590.477738  602.8155  2.444609e-31
# 87330   6    1  2000.00375  ...  590.477738  602.8155  2.261429e-39
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2042974 entries, 87326 to 30299
# Columns: 22 entries, id to S
# dtypes: float64(13), int64(2), object(7)
# memory usage: 1.2 GB

# %% [markdown]
# Then with the optimised method

# %%
df1 = fetch_hitemp(molecule='CH4', databank_name='HITEMP-CH4', isotope='1, 2, 3', load_wavenum_min=2000, load_wavenum_max=3000)

# %time df1 = calc_linestrength_eq_optimised(df1, Tref, Tgas)

print("================After computation Optimised (?)=====================")
print(df1.head())
df1.info(verbose=False, memory_usage="deep")
# Out:
# Using existing database HITEMP-CH4
# not Qref here
# Scaling equilibrium linestrength
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:54: RuntimeWarning: invalid value encountered in double_scalars
# CPU times: user 347 ms, sys: 0 ns, total: 347 ms
# Wall time: 306 ms
# ================After computation Optimised (?)=====================
#        id  iso         wav           int  ...  lmix     gp    gpp             S
# 87326   6    1  2000.00250  2.852000e-42  ...          0.0    0.0  5.941707e-42
# 87327   6    1  2000.00250  8.171000e-36  ...          0.0    0.0  1.319127e-35
# 87328   6    1  2000.00264  3.091000e-37  ...        255.0  245.0  5.060155e-37
# 87329   6    1  2000.00362  1.880000e-31  ...        123.0  117.0  2.495688e-31
# 87330   6    1  2000.00375  1.288000e-39  ...         90.0   86.0  2.308681e-39
#
# [5 rows x 20 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2042974 entries, 87326 to 30299
# Columns: 20 entries, id to S
# dtypes: float64(11), int64(2), object(7)
# memory usage: 1.1 GB

# %%
assert np.allclose(df0.S, df1.S, atol=1e-20)
